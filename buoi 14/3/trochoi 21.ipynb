# %%
import random
current_player= random.randint(0, 1)
print("Chào mừng bạn đến với trò chơi 21!")
print("trò chơi bắt đầu!!!")
while True:
    current_number=0
    while current_number < 21:
#lượt người chơi trước (random)
        if current_player==0:
     #người chơi
            while current_number < 21:
                print("mời bạn nhập một chữ số từ 1-3!")
                player_choice=int(input())
                print("bạn đã nhập số: ",player_choice)
                if 0<player_choice<4:
                    print("bạn nhập đúng quy định!")
                    current_number+=player_choice
                    print("tổng số hiện tại là: ",current_number)
                    if current_number >=21:
                        print("tổng số lớn hơn 21!")
                        print("bạn đã thua!ha ha")
                    break
                else:
                    print("bạn nhập sai quy định!mời bạn nhập lại!")
        #máy chơi
            if current_number < 21:
                player_choice2=random.randint(1,3)
                print("máy đã nhập số: ",player_choice2)
            while current_number <21:
                    current_number+=player_choice2
                    print("tổng số hiện tại là: ",current_number)
                    if current_number >= 21:
                        print("tổng số lớn hơn 21!")
                        print("bạn đã thắng!")
                    break
#lượt người chơi trước (random)
        if current_player==1:
    #máy chơi
            if current_number < 21:
                player_choice2=random.randint(1,3)
                print("máy đã nhập số: ",player_choice2)
            while current_number <21:
                    current_number+=player_choice2
                    print("tổng số hiện tại là: ",current_number)
                    if current_number >= 21:
                        print("tổng số lớn hơn 21!")
                        print("bạn đã thắng!")
                    break
    #người chơi
            while current_number < 21:
                print("mời bạn nhập một chữ số từ 1-3!")
                player_choice=int(input())
                print("bạn đã nhập số: ",player_choice)
                if 0<player_choice<4:
                    print("bạn nhập đúng quy định!")
                    current_number+=player_choice
                    print("tổng số hiện tại là: ",current_number)
                    if current_number >=21:
                        print("tổng số lớn hơn 21!")
                        print("bạn đã thua!ha ha")
                    break
                else:
                    print("bạn nhập sai quy định!mời bạn nhập lại!")
    t=int(input("nếu chơi tiếp,mời nhập 1! kết thúc trò chơi,mời nhập 0!"))
    if(t==1):
        current_player= random.randint(0, 1)
        print("trò chơi bắt đầu!")
        continue
    else:
          break
# Out:
# Chào mừng bạn đến với trò chơi 21!
# trò chơi bắt đầu!!!
# mời bạn nhập một chữ số từ 1-3!
# 5
# bạn đã nhập số:  5
# bạn nhập sai quy định!mời bạn nhập lại!
# mời bạn nhập một chữ số từ 1-3!
# 3
# bạn đã nhập số:  3
# bạn nhập đúng quy định!
# tổng số hiện tại là:  3
# máy đã nhập số:  2
# tổng số hiện tại là:  5
# mời bạn nhập một chữ số từ 1-3!
# 2
# bạn đã nhập số:  2
# bạn nhập đúng quy định!
# tổng số hiện tại là:  7
# máy đã nhập số:  1
# tổng số hiện tại là:  8
# mời bạn nhập một chữ số từ 1-3!
# 3
# bạn đã nhập số:  3
# bạn nhập đúng quy định!
# tổng số hiện tại là:  11
# máy đã nhập số:  1
# tổng số hiện tại là:  12
# mời bạn nhập một chữ số từ 1-3!
# 1
# bạn đã nhập số:  1
# bạn nhập đúng quy định!
# tổng số hiện tại là:  13
# máy đã nhập số:  1
# tổng số hiện tại là:  14
# mời bạn nhập một chữ số từ 1-3!
# 3
# bạn đã nhập số:  3
# bạn nhập đúng quy định!
# tổng số hiện tại là:  17
# máy đã nhập số:  2
# tổng số hiện tại là:  19
# mời bạn nhập một chữ số từ 1-3!
# 3
# ...

# %% [markdown]
# ###
